# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('./../base_images/papillon.jpg',0)
plt.imshow(image,'gray')
dim = np.shape(image)
print(dim)
# Out:
# (628, 1200)

# %%
imagePexilise = cv2.resize(image,(150,100),interpolation = cv2.INTER_NEAREST)
plt.imshow(imageResize,'gray')

# %%
image_methode1 = cv2.resize(imagePexilise,(150*2,100*2),interpolation = cv2.INTER_NEAREST)
plt.imshow(image_methode1,'gray')

# %%
image_methode2 = cv2.resize(imagePexilise,(150*2,100*2),interpolation = cv2.INTER_LINEAR)
plt.imshow(image_methode2,'gray')

# %%
image_methode3 = cv2.resize(imagePexilise,(150*2,100*2),interpolation = cv2.INTER_LANCZOS4 )
plt.imshow(image_methode3,'gray')

# %%
image_methode4 = cv2.resize(imagePexilise,(150*2,100*2),interpolation = cv2.INTER_CUBIC)
plt.imshow(image_methode4,'gray')
